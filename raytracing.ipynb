# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

import os
import numpy as np
from pyproj import Transformer
from math import sin, cos, radians, atan, degrees
import math

class DEMManagerXYZ:
    """
    Liest und verwaltet DEM-Daten aus einer .xyz-Datei im LV95-Koordinatensystem (EPSG:2056).
    Die Datei enthält Zeilen im Format "X Y Z".
    """
    def __init__(self, dem_path: str, skip_header=False):
        """
        dem_path: Pfad zur .xyz-Datei
        skip_header: True, falls die erste Zeile Header-Text (z.B. "X Y Z") enthält
        """
        self.dem_path = dem_path
        self.skip_header = skip_header

        self.x_coords = None
        self.y_coords = None
        self.z_grid = None

        self.load_dem()

    def load_dem(self) -> None:
        """
        Lädt die .xyz-Daten in ein 2D-Gitter (self.z_grid).
        """
        if not os.path.exists(self.dem_path):
            raise FileNotFoundError(f"DEM-Datei {self.dem_path} wurde nicht gefunden.")

        print(f"Lade .xyz DEM aus '{self.dem_path}'...")

        # Falls die erste Zeile ein Header ist ("X Y Z"), dann skiprows=1
        skiprows = 1 if self.skip_header else 0

        # Einlesen der Zeilen: jede Zeile enthält "X Y Z"
        data = np.loadtxt(self.dem_path, skiprows=skiprows)  # shape = (N, 3)

        xs = data[:, 0]
        ys = data[:, 1]
        zs = data[:, 2]

        # Eindeutige X- und Y-Werte
        unique_x = np.unique(xs)
        unique_y = np.unique(ys)

        unique_x.sort()
        unique_y.sort()

        self.x_coords = unique_x
        self.y_coords = unique_y

        nx = len(unique_x)
        ny = len(unique_y)

        # 2D-Array für Z-Werte
        z_grid = np.full((ny, nx), np.nan, dtype=np.float32)

        # Dictionaries zum schnellen Index-Mapping
        x_to_idx = {val: i for i, val in enumerate(unique_x)}
        y_to_idx = {val: j for j, val in enumerate(unique_y)}

        for x_val, y_val, z_val in data:
            c = x_to_idx[x_val]
            r = y_to_idx[y_val]
            z_grid[r, c] = z_val

        self.z_grid = z_grid
        print(f"DEM geladen. Grid-Dimension: nx={nx}, ny={ny}.")

    def get_elevation(self, x: float, y: float) -> float:
        """
        Gibt die Höhe (Z) an der Position (x, y) (LV95) via bilinearer Interpolation zurück.
        """
        # Prüfen, ob (x, y) im Gültigkeitsbereich liegt
        if x < self.x_coords[0] or x > self.x_coords[-1]:
            raise IndexError("X-Koordinate außerhalb des DEM-Bereichs.")
        if y < self.y_coords[0] or y > self.y_coords[-1]:
            raise IndexError("Y-Koordinate außerhalb des DEM-Bereichs.")

        # Indizes finden
        i1 = np.searchsorted(self.x_coords, x)
        i0 = i1 - 1
        j1 = np.searchsorted(self.y_coords, y)
        j0 = j1 - 1

        # Randfälle
        if i0 < 0:
            i0 = 0
        if i1 >= len(self.x_coords):
            i1 = len(self.x_coords) - 1
        if j0 < 0:
            j0 = 0
        if j1 >= len(self.y_coords):
            j1 = len(self.y_coords) - 1

        x0 = self.x_coords[i0]
        x1 = self.x_coords[i1]
        y0 = self.y_coords[j0]
        y1 = self.y_coords[j1]

        z00 = self.z_grid[j0, i0]
        z01 = self.z_grid[j0, i1]
        z10 = self.z_grid[j1, i0]
        z11 = self.z_grid[j1, i1]

        denom_x = (x1 - x0) if (x1 != x0) else 1e-9
        denom_y = (y1 - y0) if (y1 != y0) else 1e-9

        tx = (x - x0) / denom_x
        ty = (y - y0) / denom_y

        # Bilineare Interpolation
        z0 = z00 + (z01 - z00) * tx
        z1 = z10 + (z11 - z10) * tx
        z = z0 + (z1 - z0) * ty

        return float(z)


class EXIFData:
    """
    Enthält die (teils manuell) gesetzten EXIF-Daten.
    Wichtig ist hier v.a. GPSImgDirection (Heading).
    """
    def __init__(self):
        # Kamera-Parameter (nach Bedarf anpassen)
        self.focal_length_mm = 5.1
        self.sensor_width_mm = 5.76
        self.sensor_height_mm = 4.29
        self.image_width_px = 4032
        self.image_height_px = 3024

        # Kameraposition in WGS84 (Beispielwerte)
        self.latitude = 46.478522
        self.longitude = 8.541992
        self.altitude_m = 2273.53

        # Beispiel: GPS-Heading
        self.gps_img_direction_ref = "T"
        self.gps_img_direction_str = "650565/2048"  # ~ 359.76°
        self.gps_dest_bearing_ref = "T"
        self.gps_dest_bearing_str = "736997/2048"  # ~ 359.76°

        self.gps_img_direction_deg = self._parse_fraction(self.gps_img_direction_str)
        self.gps_dest_bearing_deg = self._parse_fraction(self.gps_dest_bearing_str)

        # Hier definieren wir, wie wir "heading_deg" bestimmen:
        self.heading_deg = self.gps_img_direction_deg

        # Neigung und Roll (hier ungenutzt)
        self.tilt_deg = 0.0
        self.roll_deg = 0.0

    def _parse_fraction(self, fraction_str: str) -> float:
        """
        Erwartet z.B. "736997/2048" und wandelt das in eine float-Zahl um.
        """
        if not fraction_str or '/' not in fraction_str:
            return 0.0
        num_str, den_str = fraction_str.split('/')
        try:
            num = float(num_str)
            den = float(den_str)
            return num / den if den != 0 else 0.0
        except ValueError:
            return 0.0

    def get_decimal_lat_lon(self) -> (float, float):
        """
        Gibt die dezimalen Latitude/Longitude aus.
        """
        return (self.latitude, self.longitude)


class ProjectionManager:
    """
    Verwaltet die Projektion und hier speziell das 3D-Raycasting
    unter Berücksichtigung des Heading und zusätzlicher Pixel-Winkel.
    """
    def __init__(self, dem_manager: DEMManagerXYZ, exif_data: EXIFData):
        self.dem_manager = dem_manager
        self.exif_data = exif_data

        # Kameraposition (WGS84)
        lat_dec, lon_dec = exif_data.get_decimal_lat_lon()
        self.camera_lat = lat_dec
        self.camera_lon = lon_dec
        self.camera_alt = exif_data.altitude_m

        # Heading (z.B. ~359.76° => fast Norden)
        self.heading_deg = exif_data.heading_deg

        # Koordinaten-Transformer
        self.transformer_to_lv95 = Transformer.from_crs("EPSG:4326", "EPSG:2056", always_xy=True)
        self.transformer_to_wgs84 = Transformer.from_crs("EPSG:2056", "EPSG:4326", always_xy=True)

        # Bildabmessungen
        self.image_width_px = exif_data.image_width_px
        self.image_height_px = exif_data.image_height_px

    def get_3d_coordinates_for_pixel(self,
                                 x_pixel: float,
                                 y_pixel: float,
                                 step_size=1.0):
        """
        Bestimmt den 3D-Schnittpunkt auf dem DEM für das Bildpixel (x_pixel, y_pixel).
        Wir brechen ausschließlich ab, wenn:
          - der Strahl die DEM-Oberfläche erreicht (test_z <= dem_h), oder
          - wir aus dem DEM-Bereich hinaustreten (IndexError).
        """
        # 1) Kamera in LV95
        cam_x_lv95, cam_y_lv95 = self.transformer_to_lv95.transform(
            self.camera_lon, self.camera_lat
        )
        cam_z_lv95 = self.camera_alt  # Kamera-Höhe

        # 2) Pixelabhängige Winkel berechnen (Beispielformel)
        zoom_factor = 2.8 # Zoomfaktor der Kamera
        alpha_vert_deg = (-1*degrees(atan(((2*x_pixel / self.image_width_px) - 1.0)* 36.0 / (2.0 * 26.0))))*(1/zoom_factor)  + 13.5 # 13.5° ist der Winkel der Kamera (Tilt), durch Approximationsverfahren ermittelt
        alpha_horiz_deg = (degrees(atan(((2*y_pixel / self.image_height_px) - 1.0) * 24.0 / (2.0 * 26.0))))*(1/zoom_factor)
        print(f"Pixel=({x_pixel}, {y_pixel}) --> alpha_vert={alpha_vert_deg:.2f}°, alpha_horiz={alpha_horiz_deg:.2f}°")

        # 3) In Radianten umwandeln und Heading hinzufügen
        heading_plus_horiz = radians(self.heading_deg + alpha_horiz_deg)
        phi = radians(alpha_vert_deg)  # vertikaler Neigungswinkel

        # 4) 3D-Richtungsvektor
        dx = sin(heading_plus_horiz) * cos(phi)
        dy = cos(heading_plus_horiz) * cos(phi)
        dz = sin(phi)

        # 5) Iteratives Voranschreiten bis Boden oder Austritt aus dem DEM
        dist = 0.0
        intersect_x = cam_x_lv95
        intersect_y = cam_y_lv95
        intersect_z = cam_z_lv95

        iteration = 0
        while True:
            iteration += 1

            test_x = cam_x_lv95 + dx * dist
            test_y = cam_y_lv95 + dy * dist
            test_z = cam_z_lv95 + dz * dist

            # Abfrage der DEM-Höhe für die Testposition
            try:
                dem_h = self.dem_manager.get_elevation(test_x, test_y)
            except IndexError:
                # Außerhalb des DEM-Bereichs -> Kein Schnittpunkt gefunden
                break

            # Jede 10. Iteration ausgeben, inkl. DEM-Höhe
            if iteration % 10 == 0:
                print(f"[Ray Iteration {iteration}] "
                      f"dist={dist:.1f}, x={test_x:.1f}, y={test_y:.1f}, "
                      f"z(Strahl)={test_z:.1f}, DEM-Höhe={dem_h:.1f}")

            # Schnitt mit der Oberfläche?
            if test_z <= dem_h:
                # Schnittpunkt genau auf die DEM-Höhe setzen
                intersect_x = test_x
                intersect_y = test_y
                intersect_z = dem_h
                break

            dist += step_size

        # 6) Rücktransform nach WGS84 (Optional)
        lon_final, lat_final = self.transformer_to_wgs84.transform(intersect_x, intersect_y)
        alt_final = intersect_z

        return lat_final, lon_final, alt_final


def main():
    # 1) DEM (LV95) aus .xyz laden
    dem_path = r".\swissalti3d_2022_2684-1148_0.5_2056_5728.xyz\SWISSALTI3D_0.5_XYZ_CHLV95_LN02_2684_1148.xyz"
    dem_manager = DEMManagerXYZ(dem_path, skip_header=True)

    # 2) EXIF-Daten
    exif_data = EXIFData()
    print("=== Kameraposition (WGS84) ===")
    print(f"Lat={exif_data.latitude:.6f}, Lon={exif_data.longitude:.6f}, Alt={exif_data.altitude_m:.2f}m")
    print(f"GPSImgDirection ~ {exif_data.gps_img_direction_deg:.2f}°")

    # 3) ProjectionManager
    proj_manager = ProjectionManager(dem_manager, exif_data)

    # 4) Drei Beispiel-Pixel
    pixel_positions = [
        (2016, 1512),
        (848, 1267),
        (3528,2628)
    ]

    print("\n=== Berechnungen für Beispiel-Pixel ===")
    for (px, py) in pixel_positions:
        lat_hit, lon_hit, alt_hit = proj_manager.get_3d_coordinates_for_pixel(
            px, py, 
            step_size=1.0
        )
        print(f"Pixel=({px}, {py}) --> lat={lat_hit:.6f}, lon={lon_hit:.6f}, alt={alt_hit:.2f}")


if __name__ == "__main__":
    main()
# Out:
# Lade .xyz DEM aus '.\swissalti3d_2022_2684-1148_0.5_2056_5728.xyz\SWISSALTI3D_0.5_XYZ_CHLV95_LN02_2684_1148.xyz'...
# DEM geladen. Grid-Dimension: nx=2000, ny=2000.
# === Kameraposition (WGS84) ===
# Lat=46.478522, Lon=8.541992, Alt=2273.53m
# GPSImgDirection ~ 317.66°
#
# === Berechnungen für Beispiel-Pixel ===
# Pixel=(2016, 1512) --> alpha_vert=13.50°, alpha_horiz=0.00°
# [Ray Iteration 10] dist=9.0, x=2684724.3, y=1148068.3, z(Strahl)=2275.6, DEM-Höhe=2272.0
# [Ray Iteration 20] dist=19.0, x=2684717.7, y=1148075.5, z(Strahl)=2278.0, DEM-Höhe=2272.2
# [Ray Iteration 30] dist=29.0, x=2684711.2, y=1148082.7, z(Strahl)=2280.3, DEM-Höhe=2274.1
# [Ray Iteration 40] dist=39.0, x=2684704.6, y=1148089.9, z(Strahl)=2282.6, DEM-Höhe=2275.6
# [Ray Iteration 50] dist=49.0, x=2684698.1, y=1148097.1, z(Strahl)=2285.0, DEM-Höhe=2275.0
# [Ray Iteration 60] dist=59.0, x=2684691.5, y=1148104.3, z(Strahl)=2287.3, DEM-Höhe=2274.8
# [Ray Iteration 70] dist=69.0, x=2684685.0, y=1148111.4, z(Strahl)=2289.6, DEM-Höhe=2278.0
# [Ray Iteration 80] dist=79.0, x=2684678.4, y=1148118.6, z(Strahl)=2292.0, DEM-Höhe=2281.2
# [Ray Iteration 90] dist=89.0, x=2684671.9, y=1148125.8, z(Strahl)=2294.3, DEM-Höhe=2281.9
# [Ray Iteration 100] dist=99.0, x=2684665.3, y=1148133.0, z(Strahl)=2296.6, DEM-Höhe=2284.0
# [Ray Iteration 110] dist=109.0, x=2684658.8, y=1148140.2, z(Strahl)=2299.0, DEM-Höhe=2286.1
# [Ray Iteration 120] dist=119.0, x=2684652.2, y=1148147.4, z(Strahl)=2301.3, DEM-Höhe=2287.1
# [Ray Iteration 130] dist=129.0, x=2684645.7, y=1148154.6, z(Strahl)=2303.6, DEM-Höhe=2287.1
# [Ray Iteration 140] dist=139.0, x=2684639.1, y=1148161.8, z(Strahl)=2306.0, DEM-Höhe=2290.2
# [Ray Iteration 150] dist=149.0, x=2684632.6, y=1148168.9, z(Strahl)=2308.3, DEM-Höhe=2294.6
# [Ray Iteration 160] dist=159.0, x=2684626.0, y=1148176.1, z(Strahl)=2310.6, DEM-Höhe=2302.7
# [Ray Iteration 170] dist=169.0, x=2684619.5, y=1148183.3, z(Strahl)=2313.0, DEM-Höhe=2308.9
# [Ray Iteration 180] dist=179.0, x=2684612.9, y=1148190.5, z(Strahl)=2315.3, DEM-Höhe=2313.6
# [Ray Iteration 190] dist=189.0, x=2684606.4, y=1148197.7, z(Strahl)=2317.7, DEM-Höhe=2315.9
# [Ray Iteration 200] dist=199.0, x=2684599.9, y=1148204.9, z(Strahl)=2320.0, DEM-Höhe=2316.7
# [Ray Iteration 210] dist=209.0, x=2684593.3, y=1148212.1, z(Strahl)=2322.3, DEM-Höhe=2319.8
# [Ray Iteration 220] dist=219.0, x=2684586.8, y=1148219.3, z(Strahl)=2324.7, DEM-Höhe=2322.4
# [Ray Iteration 230] dist=229.0, x=2684580.2, y=1148226.4, z(Strahl)=2327.0, DEM-Höhe=2321.8
# [Ray Iteration 240] dist=239.0, x=2684573.7, y=1148233.6, z(Strahl)=2329.3, DEM-Höhe=2319.5
# [Ray Iteration 250] dist=249.0, x=2684567.1, y=1148240.8, z(Strahl)=2331.7, DEM-Höhe=2319.1
# [Ray Iteration 260] dist=259.0, x=2684560.6, y=1148248.0, z(Strahl)=2334.0, DEM-Höhe=2318.2
# [Ray Iteration 270] dist=269.0, x=2684554.0, y=1148255.2, z(Strahl)=2336.3, DEM-Höhe=2316.8
# [Ray Iteration 280] dist=279.0, x=2684547.5, y=1148262.4, z(Strahl)=2338.7, DEM-Höhe=2316.8
# [Ray Iteration 290] dist=289.0, x=2684540.9, y=1148269.6, z(Strahl)=2341.0, DEM-Höhe=2315.8
# [Ray Iteration 300] dist=299.0, x=2684534.4, y=1148276.8, z(Strahl)=2343.3, DEM-Höhe=2316.3
# [Ray Iteration 310] dist=309.0, x=2684527.8, y=1148283.9, z(Strahl)=2345.7, DEM-Höhe=2322.0
# [Ray Iteration 320] dist=319.0, x=2684521.3, y=1148291.1, z(Strahl)=2348.0, DEM-Höhe=2329.8
# [Ray Iteration 330] dist=329.0, x=2684514.7, y=1148298.3, z(Strahl)=2350.3, DEM-Höhe=2341.6
# [Ray Iteration 340] dist=339.0, x=2684508.2, y=1148305.5, z(Strahl)=2352.7, DEM-Höhe=2346.1
# [Ray Iteration 350] dist=349.0, x=2684501.6, y=1148312.7, z(Strahl)=2355.0, DEM-Höhe=2345.2
# [Ray Iteration 360] dist=359.0, x=2684495.1, y=1148319.9, z(Strahl)=2357.3, DEM-Höhe=2345.9
# [Ray Iteration 370] dist=369.0, x=2684488.5, y=1148327.1, z(Strahl)=2359.7, DEM-Höhe=2345.0
# [Ray Iteration 380] dist=379.0, x=2684482.0, y=1148334.2, z(Strahl)=2362.0, DEM-Höhe=2343.3
# [Ray Iteration 390] dist=389.0, x=2684475.4, y=1148341.4, z(Strahl)=2364.3, DEM-Höhe=2341.9
# [Ray Iteration 400] dist=399.0, x=2684468.9, y=1148348.6, z(Strahl)=2366.7, DEM-Höhe=2341.2
# [Ray Iteration 410] dist=409.0, x=2684462.3, y=1148355.8, z(Strahl)=2369.0, DEM-Höhe=2340.4
# [Ray Iteration 420] dist=419.0, x=2684455.8, y=1148363.0, z(Strahl)=2371.3, DEM-Höhe=2340.0
# [Ray Iteration 430] dist=429.0, x=2684449.2, y=1148370.2, z(Strahl)=2373.7, DEM-Höhe=2339.7
# [Ray Iteration 440] dist=439.0, x=2684442.7, y=1148377.4, z(Strahl)=2376.0, DEM-Höhe=2340.3
# [Ray Iteration 450] dist=449.0, x=2684436.1, y=1148384.6, z(Strahl)=2378.3, DEM-Höhe=2339.5
# [Ray Iteration 460] dist=459.0, x=2684429.6, y=1148391.7, z(Strahl)=2380.7, DEM-Höhe=2340.9
# [Ray Iteration 470] dist=469.0, x=2684423.0, y=1148398.9, z(Strahl)=2383.0, DEM-Höhe=2341.6
# [Ray Iteration 480] dist=479.0, x=2684416.5, y=1148406.1, z(Strahl)=2385.4, DEM-Höhe=2344.0
# [Ray Iteration 490] dist=489.0, x=2684409.9, y=1148413.3, z(Strahl)=2387.7, DEM-Höhe=2345.6
# [Ray Iteration 500] dist=499.0, x=2684403.4, y=1148420.5, z(Strahl)=2390.0, DEM-Höhe=2347.7
# [Ray Iteration 510] dist=509.0, x=2684396.8, y=1148427.7, z(Strahl)=2392.4, DEM-Höhe=2350.9
# [Ray Iteration 520] dist=519.0, x=2684390.3, y=1148434.9, z(Strahl)=2394.7, DEM-Höhe=2354.3
# [Ray Iteration 530] dist=529.0, x=2684383.7, y=1148442.1, z(Strahl)=2397.0, DEM-Höhe=2357.9
# [Ray Iteration 540] dist=539.0, x=2684377.2, y=1148449.2, z(Strahl)=2399.4, DEM-Höhe=2362.9
# [Ray Iteration 550] dist=549.0, x=2684370.6, y=1148456.4, z(Strahl)=2401.7, DEM-Höhe=2368.6
# [Ray Iteration 560] dist=559.0, x=2684364.1, y=1148463.6, z(Strahl)=2404.0, DEM-Höhe=2376.4
# [Ray Iteration 570] dist=569.0, x=2684357.5, y=1148470.8, z(Strahl)=2406.4, DEM-Höhe=2388.2
# [Ray Iteration 580] dist=579.0, x=2684351.0, y=1148478.0, z(Strahl)=2408.7, DEM-Höhe=2397.3
# [Ray Iteration 590] dist=589.0, x=2684344.4, y=1148485.2, z(Strahl)=2411.0, DEM-Höhe=2404.0
# [Ray Iteration 600] dist=599.0, x=2684337.9, y=1148492.4, z(Strahl)=2413.4, DEM-Höhe=2409.0
# [Ray Iteration 610] dist=609.0, x=2684331.3, y=1148499.6, z(Strahl)=2415.7, DEM-Höhe=2416.1
# Pixel=(2016, 1512) --> lat=46.482509, lon=8.536879, alt=2416.06
# Pixel=(848, 1267) --> alpha_vert=21.31°, alpha_horiz=-1.53°
# [Ray Iteration 10] dist=9.0, x=2684724.4, y=1148067.9, z(Strahl)=2276.8, DEM-Höhe=2272.1
# [Ray Iteration 20] dist=19.0, x=2684717.9, y=1148074.6, z(Strahl)=2280.4, DEM-Höhe=2272.3
# [Ray Iteration 30] dist=29.0, x=2684711.5, y=1148081.3, z(Strahl)=2284.1, DEM-Höhe=2273.7
# [Ray Iteration 40] dist=39.0, x=2684705.0, y=1148088.0, z(Strahl)=2287.7, DEM-Höhe=2275.1
# [Ray Iteration 50] dist=49.0, x=2684698.5, y=1148094.8, z(Strahl)=2291.3, DEM-Höhe=2276.2
# [Ray Iteration 60] dist=59.0, x=2684692.1, y=1148101.5, z(Strahl)=2295.0, DEM-Höhe=2277.5
# [Ray Iteration 70] dist=69.0, x=2684685.6, y=1148108.2, z(Strahl)=2298.6, DEM-Höhe=2278.4
# [Ray Iteration 80] dist=79.0, x=2684679.2, y=1148114.9, z(Strahl)=2302.2, DEM-Höhe=2280.4
# [Ray Iteration 90] dist=89.0, x=2684672.7, y=1148121.6, z(Strahl)=2305.9, DEM-Höhe=2282.1
# [Ray Iteration 100] dist=99.0, x=2684666.3, y=1148128.3, z(Strahl)=2309.5, DEM-Höhe=2283.9
# [Ray Iteration 110] dist=109.0, x=2684659.8, y=1148135.1, z(Strahl)=2313.1, DEM-Höhe=2287.8
# [Ray Iteration 120] dist=119.0, x=2684653.4, y=1148141.8, z(Strahl)=2316.8, DEM-Höhe=2288.1
# [Ray Iteration 130] dist=129.0, x=2684646.9, y=1148148.5, z(Strahl)=2320.4, DEM-Höhe=2288.1
# [Ray Iteration 140] dist=139.0, x=2684640.4, y=1148155.2, z(Strahl)=2324.0, DEM-Höhe=2289.2
# [Ray Iteration 150] dist=149.0, x=2684634.0, y=1148161.9, z(Strahl)=2327.7, DEM-Höhe=2292.5
# [Ray Iteration 160] dist=159.0, x=2684627.5, y=1148168.6, z(Strahl)=2331.3, DEM-Höhe=2296.8
# [Ray Iteration 170] dist=169.0, x=2684621.1, y=1148175.4, z(Strahl)=2334.9, DEM-Höhe=2305.0
# [Ray Iteration 180] dist=179.0, x=2684614.6, y=1148182.1, z(Strahl)=2338.6, DEM-Höhe=2310.6
# [Ray Iteration 190] dist=189.0, x=2684608.2, y=1148188.8, z(Strahl)=2342.2, DEM-Höhe=2315.0
# [Ray Iteration 200] dist=199.0, x=2684601.7, y=1148195.5, z(Strahl)=2345.8, DEM-Höhe=2317.1
# [Ray Iteration 210] dist=209.0, x=2684595.2, y=1148202.2, z(Strahl)=2349.5, DEM-Höhe=2318.5
# [Ray Iteration 220] dist=219.0, x=2684588.8, y=1148208.9, z(Strahl)=2353.1, DEM-Höhe=2320.6
# [Ray Iteration 230] dist=229.0, x=2684582.3, y=1148215.7, z(Strahl)=2356.7, DEM-Höhe=2323.0
# [Ray Iteration 240] dist=239.0, x=2684575.9, y=1148222.4, z(Strahl)=2360.4, DEM-Höhe=2322.8
# [Ray Iteration 250] dist=249.0, x=2684569.4, y=1148229.1, z(Strahl)=2364.0, DEM-Höhe=2321.8
# [Ray Iteration 260] dist=259.0, x=2684563.0, y=1148235.8, z(Strahl)=2367.6, DEM-Höhe=2321.5
# [Ray Iteration 270] dist=269.0, x=2684556.5, y=1148242.5, z(Strahl)=2371.3, DEM-Höhe=2320.6
# [Ray Iteration 280] dist=279.0, x=2684550.0, y=1148249.2, z(Strahl)=2374.9, DEM-Höhe=2319.3
# [Ray Iteration 290] dist=289.0, x=2684543.6, y=1148256.0, z(Strahl)=2378.5, DEM-Höhe=2319.1
# [Ray Iteration 300] dist=299.0, x=2684537.1, y=1148262.7, z(Strahl)=2382.2, DEM-Höhe=2319.7
# [Ray Iteration 310] dist=309.0, x=2684530.7, y=1148269.4, z(Strahl)=2385.8, DEM-Höhe=2317.5
# [Ray Iteration 320] dist=319.0, x=2684524.2, y=1148276.1, z(Strahl)=2389.4, DEM-Höhe=2322.5
# [Ray Iteration 330] dist=329.0, x=2684517.8, y=1148282.8, z(Strahl)=2393.1, DEM-Höhe=2328.2
# [Ray Iteration 340] dist=339.0, x=2684511.3, y=1148289.5, z(Strahl)=2396.7, DEM-Höhe=2340.9
# [Ray Iteration 350] dist=349.0, x=2684504.9, y=1148296.3, z(Strahl)=2400.3, DEM-Höhe=2346.1
# [Ray Iteration 360] dist=359.0, x=2684498.4, y=1148303.0, z(Strahl)=2404.0, DEM-Höhe=2347.9
# [Ray Iteration 370] dist=369.0, x=2684491.9, y=1148309.7, z(Strahl)=2407.6, DEM-Höhe=2347.7
# [Ray Iteration 380] dist=379.0, x=2684485.5, y=1148316.4, z(Strahl)=2411.2, DEM-Höhe=2348.1
# [Ray Iteration 390] dist=389.0, x=2684479.0, y=1148323.1, z(Strahl)=2414.9, DEM-Höhe=2347.1
# [Ray Iteration 400] dist=399.0, x=2684472.6, y=1148329.8, z(Strahl)=2418.5, DEM-Höhe=2345.4
# [Ray Iteration 410] dist=409.0, x=2684466.1, y=1148336.6, z(Strahl)=2422.1, DEM-Höhe=2344.5
# [Ray Iteration 420] dist=419.0, x=2684459.7, y=1148343.3, z(Strahl)=2425.8, DEM-Höhe=2343.6
# [Ray Iteration 430] dist=429.0, x=2684453.2, y=1148350.0, z(Strahl)=2429.4, DEM-Höhe=2342.3
# [Ray Iteration 440] dist=439.0, x=2684446.7, y=1148356.7, z(Strahl)=2433.0, DEM-Höhe=2342.1
# [Ray Iteration 450] dist=449.0, x=2684440.3, y=1148363.4, z(Strahl)=2436.7, DEM-Höhe=2341.5
# [Ray Iteration 460] dist=459.0, x=2684433.8, y=1148370.1, z(Strahl)=2440.3, DEM-Höhe=2341.6
# [Ray Iteration 470] dist=469.0, x=2684427.4, y=1148376.9, z(Strahl)=2443.9, DEM-Höhe=2340.8
# [Ray Iteration 480] dist=479.0, x=2684420.9, y=1148383.6, z(Strahl)=2447.6, DEM-Höhe=2341.1
# [Ray Iteration 490] dist=489.0, x=2684414.5, y=1148390.3, z(Strahl)=2451.2, DEM-Höhe=2341.8
# [Ray Iteration 500] dist=499.0, x=2684408.0, y=1148397.0, z(Strahl)=2454.8, DEM-Höhe=2343.9
# [Ray Iteration 510] dist=509.0, x=2684401.5, y=1148403.7, z(Strahl)=2458.5, DEM-Höhe=2345.7
# [Ray Iteration 520] dist=519.0, x=2684395.1, y=1148410.4, z(Strahl)=2462.1, DEM-Höhe=2348.5
# [Ray Iteration 530] dist=529.0, x=2684388.6, y=1148417.2, z(Strahl)=2465.7, DEM-Höhe=2351.2
# [Ray Iteration 540] dist=539.0, x=2684382.2, y=1148423.9, z(Strahl)=2469.4, DEM-Höhe=2354.6
# [Ray Iteration 550] dist=549.0, x=2684375.7, y=1148430.6, z(Strahl)=2473.0, DEM-Höhe=2359.1
# [Ray Iteration 560] dist=559.0, x=2684369.3, y=1148437.3, z(Strahl)=2476.6, DEM-Höhe=2362.6
# [Ray Iteration 570] dist=569.0, x=2684362.8, y=1148444.0, z(Strahl)=2480.3, DEM-Höhe=2366.4
# [Ray Iteration 580] dist=579.0, x=2684356.4, y=1148450.7, z(Strahl)=2483.9, DEM-Höhe=2372.5
# [Ray Iteration 590] dist=589.0, x=2684349.9, y=1148457.5, z(Strahl)=2487.5, DEM-Höhe=2378.1
# [Ray Iteration 600] dist=599.0, x=2684343.4, y=1148464.2, z(Strahl)=2491.2, DEM-Höhe=2385.4
# [Ray Iteration 610] dist=609.0, x=2684337.0, y=1148470.9, z(Strahl)=2494.8, DEM-Höhe=2397.7
# [Ray Iteration 620] dist=619.0, x=2684330.5, y=1148477.6, z(Strahl)=2498.4, DEM-Höhe=2404.9
# [Ray Iteration 630] dist=629.0, x=2684324.1, y=1148484.3, z(Strahl)=2502.1, DEM-Höhe=2410.9
# [Ray Iteration 640] dist=639.0, x=2684317.6, y=1148491.0, z(Strahl)=2505.7, DEM-Höhe=2415.1
# [Ray Iteration 650] dist=649.0, x=2684311.2, y=1148497.8, z(Strahl)=2509.3, DEM-Höhe=2421.5
# [Ray Iteration 660] dist=659.0, x=2684304.7, y=1148504.5, z(Strahl)=2513.0, DEM-Höhe=2426.8
# [Ray Iteration 670] dist=669.0, x=2684298.2, y=1148511.2, z(Strahl)=2516.6, DEM-Höhe=2431.6
# [Ray Iteration 680] dist=679.0, x=2684291.8, y=1148517.9, z(Strahl)=2520.2, DEM-Höhe=2436.6
# [Ray Iteration 690] dist=689.0, x=2684285.3, y=1148524.6, z(Strahl)=2523.9, DEM-Höhe=2442.0
# [Ray Iteration 700] dist=699.0, x=2684278.9, y=1148531.3, z(Strahl)=2527.5, DEM-Höhe=2448.3
# [Ray Iteration 710] dist=709.0, x=2684272.4, y=1148538.1, z(Strahl)=2531.1, DEM-Höhe=2454.8
# [Ray Iteration 720] dist=719.0, x=2684266.0, y=1148544.8, z(Strahl)=2534.8, DEM-Höhe=2463.6
# [Ray Iteration 730] dist=729.0, x=2684259.5, y=1148551.5, z(Strahl)=2538.4, DEM-Höhe=2478.1
# [Ray Iteration 740] dist=739.0, x=2684253.0, y=1148558.2, z(Strahl)=2542.0, DEM-Höhe=2485.4
# [Ray Iteration 750] dist=749.0, x=2684246.6, y=1148564.9, z(Strahl)=2545.7, DEM-Höhe=2491.7
# [Ray Iteration 760] dist=759.0, x=2684240.1, y=1148571.6, z(Strahl)=2549.3, DEM-Höhe=2499.3
# [Ray Iteration 770] dist=769.0, x=2684233.7, y=1148578.4, z(Strahl)=2552.9, DEM-Höhe=2508.4
# [Ray Iteration 780] dist=779.0, x=2684227.2, y=1148585.1, z(Strahl)=2556.6, DEM-Höhe=2512.3
# [Ray Iteration 790] dist=789.0, x=2684220.8, y=1148591.8, z(Strahl)=2560.2, DEM-Höhe=2522.1
# [Ray Iteration 800] dist=799.0, x=2684214.3, y=1148598.5, z(Strahl)=2563.8, DEM-Höhe=2528.3
# [Ray Iteration 810] dist=809.0, x=2684207.9, y=1148605.2, z(Strahl)=2567.5, DEM-Höhe=2534.4
# [Ray Iteration 820] dist=819.0, x=2684201.4, y=1148611.9, z(Strahl)=2571.1, DEM-Höhe=2539.8
# [Ray Iteration 830] dist=829.0, x=2684194.9, y=1148618.7, z(Strahl)=2574.7, DEM-Höhe=2546.4
# [Ray Iteration 840] dist=839.0, x=2684188.5, y=1148625.4, z(Strahl)=2578.4, DEM-Höhe=2554.3
# [Ray Iteration 850] dist=849.0, x=2684182.0, y=1148632.1, z(Strahl)=2582.0, DEM-Höhe=2560.7
# [Ray Iteration 860] dist=859.0, x=2684175.6, y=1148638.8, z(Strahl)=2585.6, DEM-Höhe=2565.5
# [Ray Iteration 870] dist=869.0, x=2684169.1, y=1148645.5, z(Strahl)=2589.3, DEM-Höhe=2573.3
# [Ray Iteration 880] dist=879.0, x=2684162.7, y=1148652.2, z(Strahl)=2592.9, DEM-Höhe=2587.3
# Pixel=(848, 1267) --> lat=46.483959, lon=8.534636, alt=2596.72
# Pixel=(3528, 2628) --> alpha_vert=3.70°, alpha_horiz=6.72°
# [Ray Iteration 10] dist=9.0, x=2684725.0, y=1148069.2, z(Strahl)=2274.1, DEM-Höhe=2271.7
# [Ray Iteration 20] dist=19.0, x=2684719.1, y=1148077.3, z(Strahl)=2274.8, DEM-Höhe=2271.7
# [Ray Iteration 30] dist=29.0, x=2684713.3, y=1148085.4, z(Strahl)=2275.4, DEM-Höhe=2273.4
# [Ray Iteration 40] dist=39.0, x=2684707.5, y=1148093.5, z(Strahl)=2276.0, DEM-Höhe=2274.2
# [Ray Iteration 50] dist=49.0, x=2684701.7, y=1148101.6, z(Strahl)=2276.7, DEM-Höhe=2275.1
# [Ray Iteration 60] dist=59.0, x=2684695.9, y=1148109.7, z(Strahl)=2277.3, DEM-Höhe=2275.4
# [Ray Iteration 70] dist=69.0, x=2684690.1, y=1148117.8, z(Strahl)=2278.0, DEM-Höhe=2276.6
# Pixel=(3528, 2628) --> lat=46.479075, lon=8.541436, alt=2279.12
